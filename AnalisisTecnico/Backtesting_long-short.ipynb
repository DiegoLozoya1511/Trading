# %%
import pandas as pd
import matplotlib.pyplot as plt
import ta
from dataclasses import dataclass

plt.rcParams['figure.facecolor'] = 'lightgrey'
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['axes.grid'] = True
plt.rcParams['grid.alpha'] = 0.5
plt.rcParams['grid.linestyle'] = '--'
plt.rcParams['axes.titleweight'] = 'bold'
plt.rcParams['axes.titlesize'] = 16
plt.rcParams['axes.labelsize'] = 12
plt.rcParams['legend.frameon'] = True
plt.rcParams['legend.facecolor'] = 'white'
plt.rcParams['legend.edgecolor'] = 'black'

colors = ["cornflowerblue", "indianred", "darkseagreen", "plum", "dimgray"]

# %%
data = pd.read_csv('Data/aapl_5m_train.csv').drop(columns=['Unnamed: 0', 'Timestamp', 'Gmtoffset']).dropna()

rsi_indicator = ta.momentum.RSIIndicator(data.Close, window=15)
data['rsi'] = rsi_indicator.rsi()

rsi_down = 20
rsi_up = 80
data['buy_signal'] = data['rsi'] < rsi_down
data['sell_signal'] = data['rsi'] > rsi_up

data = data.dropna().reset_index(drop=True)
data.head()
# Out:
#               Datetime        Open        High         Low       Close  \
# 0  2021-01-04 15:40:00  131.111297  131.309997  131.029998  131.044998
# 1  2021-01-04 15:45:00  131.044006  131.044006  130.479995  130.749893
# 2  2021-01-04 15:50:00  130.750000  130.830001  130.449996  130.709793
# 3  2021-01-04 15:55:00  130.700103  131.250000  130.699996  131.000000
# 4  2021-01-04 16:00:00  131.134994  131.309997  130.160003  130.309997
#
#       Volume        rsi  buy_signal  sell_signal
# 0  1253385.0  35.472015       False        False
# 1  1730254.0  31.779676       False        False
# 2  1887654.0  31.305254       False        False
# 3  1608419.0  38.432075       False        False
# 4  2055970.0  30.398179       False        False

# %%
plt.figure()
plt.plot(data.Close, color = colors[0])
plt.title('AAPL Close Price')
plt.xlabel('Time')
plt.ylabel('Price ($)')
plt.show()

plt.figure()
plt.plot(data.rsi, color = colors[0], label='RSI')
plt.axhline(rsi_down, color = colors[1], linestyle='--')
plt.axhline(rsi_up, color = colors[1], linestyle='--', label='Overbought/Oversold Levels')
plt.title('RSI with Buy/Sell Signals')
plt.xlabel('Time')
plt.ylabel('RSI Value')
plt.legend()
plt.show()

# %% [markdown]
# - Comisiones = 0.125%
# - No hay Impuestos
# - Margin Account = 50%
# - $ 1,000,000 USD Cash
# - N Shares = 50
# - Stop Loss, Take Profit = 6%
# - Buy/Sell at close
# - Borrow Rate = 0.25%

# %%
COM = 0.125 / 100
BORROW_RATE = 0.25 / 100
ADJUSTED_BORROW_RATE = BORROW_RATE / (252 * 6.5 * 60 / 5)

# DOF
STOP_LOSS = 0.6
TAKE_PROFIT = 0.06
N_SHARES = 50

INITIAL_MARGIN = 0.5
MANTEINANCE_MARGIN = 0.25

capital = 1_000_000
margin_account = 0

portfolio_value = [capital]

active_long_positions  = []
active_short_positions = []

# %%
@dataclass
class Position:
    """
    Data class for a trading position
    """
    ticker: str               # Ticker symbol
    n_shares: int             # Number of shares
    price: float              # Entry price
    time: str                 # Time position was opened
    sl: float                 # Stop loss level
    tp: float                 # Take profit level
    position_type: str        # 'long' or 'short'
    margin_account: float     # Margin account balance at position opening; 0 if long
    margin_requirement: float # Margin requirement for the position; 0 if long

# Function to calculate portfolio value
def get_portfolio_value(capital, long_positions, short_positions, current_price, n_shares):
    # Long positions are valued at current market price
    value = capital
    value += len(long_positions) * n_shares * current_price
    # Short positions are valued based on the margin account, margin requirement, and cost to buy to cover
    for position in short_positions:
        buy_to_cover_cost = current_price * position.n_shares * (1 + COM)
        value += position.margin_account + position.margin_requirement - buy_to_cover_cost

    return value

# %%
for i, row in data.iterrows():
    # === CHECK ACTIVE ORDERS === #

    # --- LONG --- #
    for position in active_long_positions.copy():
        # Stop loss or take profit check
        if row.Close > position.tp or row.Close < position.sl:
            # Add profit / losses to capital
            capital += row.Close * position.n_shares * (1 - COM)
            # Remove position from active pos
            active_long_positions.remove(position)
            continue 

    # --- SHORT --- #
    for position in active_short_positions.copy():
        # Discount borrow cost for active ahort positions
        buy_to_cover_cost = row.Close * position.n_shares * (1 + COM)
        position.margin_account -= row.Close * position.n_shares * ADJUSTED_BORROW_RATE

        # Short position status
        required_equity = buy_to_cover_cost * MANTEINANCE_MARGIN
        equity = position.margin_account + position.margin_requirement - buy_to_cover_cost

        # Margin call check
        if equity < required_equity:
            # Calculate margin call value
            margin_call = required_equity - equity
            # Print margin call info
            print(f'=== MARGIN CALL INFO ===\n' +
                  f'Margin call for {position.ticker} at {row.Datetime}\n' +
                  f'Equity required: ${required_equity:,.2f}\n' +
                  f'Equity available: ${equity:,.2f}\n' +
                  f'Margin call: ${margin_call:,.2f}\n' +
                   '======================== \n')
            # Update margin account
            position.margin_account += margin_call
            
            # Discount margin call from capital if available, else close position
            if capital > margin_call:
                capital -= margin_call
            else:
                capital += position.margin_account + position.margin_requirement - buy_to_cover_cost
                active_short_positions.remove(position) 
                continue

        # Check stop loss or take profit if not margin call
        else:
            # Stop loss or take profit check
            if row.Close < position.tp or row.Close > position.sl:
                # Add profit / losses to capital
                capital += position.margin_account + position.margin_requirement - buy_to_cover_cost
                # Remove position from active pos
                active_short_positions.remove(position)
                continue


    # === CHECK NEW SIGNALS === #

    # --- LONG --- #
    if row.buy_signal:
        cost = row.Close * N_SHARES * (1 + COM)
        # Do we have enough cash?
        if capital > cost:
            # Discount cash
            capital -= cost
            # Add position to portfolio
            pos = Position(ticker             = 'AAPL', 
                           n_shares           = N_SHARES, 
                           price              = row.Close, 
                           time               = row.Datetime,
                           sl                 = row.Close * (1 - STOP_LOSS), 
                           tp                 = row.Close * (1 + TAKE_PROFIT),
                           position_type      = 'long', 
                           margin_account     = 0, 
                           margin_requirement = 0)
            active_long_positions.append(pos)
            continue 

    # --- SHORT --- #
    if row.sell_signal:
        required_margin = row.Close * N_SHARES * INITIAL_MARGIN
        # Do we have enough cash?
        if capital > required_margin:
            # Define margin account
            margin_account = row.Close * N_SHARES * (1 - COM)
            # Discount cash
            capital -= required_margin
            # Add position to portfolio
            pos = Position(ticker             = 'AAPL', 
                           n_shares           = N_SHARES, 
                           price              = row.Close, 
                           time               = row.Datetime,
                           sl                 = row.Close * (1 + STOP_LOSS), 
                           tp                 = row.Close * (1 - TAKE_PROFIT),
                           position_type      = 'short', 
                           margin_account     = margin_account, 
                           margin_requirement = required_margin)
            active_short_positions.append(pos)

    # Calculate portfolio value at the end of the iteration
    portfolio_value.append(get_portfolio_value(capital, active_long_positions, active_short_positions, row.Close, N_SHARES))

# At the end of the backtesting, we should close all active positions
# --- LONG ---
capital += row.Close * len(active_long_positions)  * N_SHARES * (1 - COM)
active_long_positions  = []

# --- SHORT ---
for position in active_short_positions:
    buy_to_cover_cost = row.Close * position.n_shares * (1 + COM)
    capital += position.margin_account + position.margin_requirement - buy_to_cover_cost
active_short_positions = []
# Out:
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 13:50:00
# Equity required: $1,829.66
# Equity available: $1,828.00
# Margin call: $1.66
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 13:50:00
# Equity required: $1,829.66
# Equity available: $1,825.13
# Margin call: $4.53
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 13:50:00
# Equity required: $1,829.66
# Equity available: $1,826.48
# Margin call: $3.18
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 13:55:00
# Equity required: $1,831.60
# Equity available: $1,821.90
# Margin call: $9.70
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 13:55:00
# Equity required: $1,831.60
# Equity available: $1,821.90
# Margin call: $9.70
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 13:55:00
# Equity required: $1,831.60
# Equity available: $1,821.90
# Margin call: $9.70
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 14:00:00
# Equity required: $1,831.66
# Equity available: $1,831.35
# Margin call: $0.31
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 14:00:00
# Equity required: $1,831.66
# Equity available: $1,831.35
# Margin call: $0.31
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 14:00:00
# Equity required: $1,831.66
# Equity available: $1,831.35
# Margin call: $0.31
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 14:10:00
# Equity required: $1,832.16
# Equity available: $1,829.66
# Margin call: $2.50
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 14:10:00
# Equity required: $1,832.16
# Equity available: $1,829.66
# Margin call: $2.50
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 14:10:00
# Equity required: $1,832.16
# Equity available: $1,829.66
# Margin call: $2.50
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 14:15:00
# Equity required: $1,837.04
# Equity available: $1,812.64
# Margin call: $24.41
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 14:15:00
# Equity required: $1,837.04
# Equity available: $1,815.70
# Margin call: $21.34
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 14:15:00
# Equity required: $1,837.04
# Equity available: $1,812.64
# Margin call: $24.41
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 14:15:00
# Equity required: $1,837.04
# Equity available: $1,812.64
# Margin call: $24.41
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 14:15:00
# Equity required: $1,837.04
# Equity available: $1,831.18
# Margin call: $5.86
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:00:00
# Equity required: $1,837.98
# Equity available: $1,833.28
# Margin call: $4.70
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:00:00
# Equity required: $1,837.98
# Equity available: $1,833.28
# Margin call: $4.70
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:00:00
# Equity required: $1,837.98
# Equity available: $1,833.28
# Margin call: $4.70
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:00:00
# Equity required: $1,837.98
# Equity available: $1,833.28
# Margin call: $4.70
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:00:00
# Equity required: $1,837.98
# Equity available: $1,833.28
# Margin call: $4.70
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:10:00
# Equity required: $1,838.08
# Equity available: $1,837.59
# Margin call: $0.49
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:10:00
# Equity required: $1,838.08
# Equity available: $1,837.59
# Margin call: $0.49
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:10:00
# Equity required: $1,838.08
# Equity available: $1,837.59
# Margin call: $0.49
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:10:00
# Equity required: $1,838.08
# Equity available: $1,837.59
# Margin call: $0.49
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:10:00
# Equity required: $1,838.08
# Equity available: $1,837.59
# Margin call: $0.49
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:15:00
# Equity required: $1,841.55
# Equity available: $1,824.21
# Margin call: $17.34
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:15:00
# Equity required: $1,841.55
# Equity available: $1,824.21
# Margin call: $17.34
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:15:00
# Equity required: $1,841.55
# Equity available: $1,824.21
# Margin call: $17.34
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:15:00
# Equity required: $1,841.55
# Equity available: $1,824.21
# Margin call: $17.34
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:15:00
# Equity required: $1,841.55
# Equity available: $1,824.21
# Margin call: $17.34
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:15:00
# Equity required: $1,841.55
# Equity available: $1,836.00
# Margin call: $5.54
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:15:00
# Equity required: $1,841.55
# Equity available: $1,833.39
# Margin call: $8.16
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:25:00
# Equity required: $1,842.68
# Equity available: $1,837.04
# Margin call: $5.64
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:25:00
# Equity required: $1,842.68
# Equity available: $1,837.04
# Margin call: $5.64
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:25:00
# Equity required: $1,842.68
# Equity available: $1,837.04
# Margin call: $5.64
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:25:00
# Equity required: $1,842.68
# Equity available: $1,837.04
# Margin call: $5.64
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:25:00
# Equity required: $1,842.68
# Equity available: $1,837.04
# Margin call: $5.64
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:25:00
# Equity required: $1,842.68
# Equity available: $1,837.04
# Margin call: $5.64
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:25:00
# Equity required: $1,842.68
# Equity available: $1,839.67
# Margin call: $3.01
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:25:00
# Equity required: $1,842.68
# Equity available: $1,837.49
# Margin call: $5.18
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:25:00
# Equity required: $1,842.68
# Equity available: $1,837.04
# Margin call: $5.64
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:40:00
# Equity required: $1,843.28
# Equity available: $1,840.26
# Margin call: $3.02
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:40:00
# Equity required: $1,843.28
# Equity available: $1,840.26
# Margin call: $3.02
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:40:00
# Equity required: $1,843.28
# Equity available: $1,840.26
# Margin call: $3.02
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:40:00
# Equity required: $1,843.28
# Equity available: $1,840.26
# Margin call: $3.02
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:40:00
# Equity required: $1,843.28
# Equity available: $1,840.26
# Margin call: $3.02
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:40:00
# Equity required: $1,843.28
# Equity available: $1,840.26
# Margin call: $3.02
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:40:00
# Equity required: $1,843.28
# Equity available: $1,840.26
# Margin call: $3.02
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:40:00
# Equity required: $1,843.28
# Equity available: $1,840.26
# Margin call: $3.02
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:40:00
# Equity required: $1,843.28
# Equity available: $1,840.26
# Margin call: $3.02
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:50:00
# Equity required: $1,843.30
# Equity available: $1,843.18
# Margin call: $0.12
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:50:00
# Equity required: $1,843.30
# Equity available: $1,843.18
# Margin call: $0.12
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:50:00
# Equity required: $1,843.30
# Equity available: $1,843.18
# Margin call: $0.12
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:50:00
# Equity required: $1,843.30
# Equity available: $1,843.18
# Margin call: $0.12
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:50:00
# Equity required: $1,843.30
# Equity available: $1,843.18
# Margin call: $0.12
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:50:00
# Equity required: $1,843.30
# Equity available: $1,843.18
# Margin call: $0.12
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:50:00
# Equity required: $1,843.30
# Equity available: $1,843.18
# Margin call: $0.12
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:50:00
# Equity required: $1,843.30
# Equity available: $1,843.18
# Margin call: $0.12
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:50:00
# Equity required: $1,843.30
# Equity available: $1,843.18
# Margin call: $0.12
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:55:00
# Equity required: $1,845.43
# Equity available: $1,842.96
# Margin call: $2.47
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:55:00
# Equity required: $1,845.43
# Equity available: $1,834.80
# Margin call: $10.63
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:55:00
# Equity required: $1,845.43
# Equity available: $1,834.80
# Margin call: $10.63
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:55:00
# Equity required: $1,845.43
# Equity available: $1,834.80
# Margin call: $10.63
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:55:00
# Equity required: $1,845.43
# Equity available: $1,834.80
# Margin call: $10.63
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:55:00
# Equity required: $1,845.43
# Equity available: $1,834.80
# Margin call: $10.63
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:55:00
# Equity required: $1,845.43
# Equity available: $1,834.80
# Margin call: $10.63
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:55:00
# Equity required: $1,845.43
# Equity available: $1,834.80
# Margin call: $10.63
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:55:00
# Equity required: $1,845.43
# Equity available: $1,834.80
# Margin call: $10.63
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-13 15:55:00
# Equity required: $1,845.43
# Equity available: $1,834.80
# Margin call: $10.63
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 13:30:00
# Equity required: $1,860.95
# Equity available: $1,783.30
# Margin call: $77.65
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 13:30:00
# Equity required: $1,860.95
# Equity available: $1,786.86
# Margin call: $74.09
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 13:30:00
# Equity required: $1,860.95
# Equity available: $1,787.98
# Margin call: $72.97
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 13:30:00
# Equity required: $1,860.95
# Equity available: $1,783.30
# Margin call: $77.65
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 13:30:00
# Equity required: $1,860.95
# Equity available: $1,783.30
# Margin call: $77.65
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 13:30:00
# Equity required: $1,860.95
# Equity available: $1,783.30
# Margin call: $77.65
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 13:30:00
# Equity required: $1,860.95
# Equity available: $1,783.30
# Margin call: $77.65
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 13:30:00
# Equity required: $1,860.95
# Equity available: $1,783.30
# Margin call: $77.65
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 13:30:00
# Equity required: $1,860.95
# Equity available: $1,783.30
# Margin call: $77.65
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 13:30:00
# Equity required: $1,860.95
# Equity available: $1,783.30
# Margin call: $77.65
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 13:30:00
# Equity required: $1,860.95
# Equity available: $1,783.30
# Margin call: $77.65
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 13:30:00
# Equity required: $1,860.95
# Equity available: $1,783.30
# Margin call: $77.65
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 13:30:00
# Equity required: $1,860.95
# Equity available: $1,849.89
# Margin call: $11.06
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:00:00
# Equity required: $1,863.80
# Equity available: $1,849.54
# Margin call: $14.26
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:00:00
# Equity required: $1,863.80
# Equity available: $1,849.54
# Margin call: $14.26
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:00:00
# Equity required: $1,863.80
# Equity available: $1,849.54
# Margin call: $14.26
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:00:00
# Equity required: $1,863.80
# Equity available: $1,849.54
# Margin call: $14.26
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:00:00
# Equity required: $1,863.80
# Equity available: $1,849.54
# Margin call: $14.26
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:00:00
# Equity required: $1,863.80
# Equity available: $1,849.54
# Margin call: $14.26
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:00:00
# Equity required: $1,863.80
# Equity available: $1,849.54
# Margin call: $14.26
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:00:00
# Equity required: $1,863.80
# Equity available: $1,849.54
# Margin call: $14.26
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:00:00
# Equity required: $1,863.80
# Equity available: $1,849.54
# Margin call: $14.26
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:00:00
# Equity required: $1,863.80
# Equity available: $1,849.54
# Margin call: $14.26
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:00:00
# Equity required: $1,863.80
# Equity available: $1,849.54
# Margin call: $14.26
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:00:00
# Equity required: $1,863.80
# Equity available: $1,849.54
# Margin call: $14.26
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:00:00
# Equity required: $1,863.80
# Equity available: $1,849.54
# Margin call: $14.26
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:50:00
# Equity required: $1,866.96
# Equity available: $1,851.17
# Margin call: $15.79
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:50:00
# Equity required: $1,866.96
# Equity available: $1,851.17
# Margin call: $15.79
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:50:00
# Equity required: $1,866.96
# Equity available: $1,851.17
# Margin call: $15.79
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:50:00
# Equity required: $1,866.96
# Equity available: $1,851.17
# Margin call: $15.79
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:50:00
# Equity required: $1,866.96
# Equity available: $1,851.17
# Margin call: $15.79
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:50:00
# Equity required: $1,866.96
# Equity available: $1,851.17
# Margin call: $15.79
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:50:00
# Equity required: $1,866.96
# Equity available: $1,851.17
# Margin call: $15.79
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:50:00
# Equity required: $1,866.96
# Equity available: $1,851.17
# Margin call: $15.79
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:50:00
# Equity required: $1,866.96
# Equity available: $1,851.17
# Margin call: $15.79
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:50:00
# Equity required: $1,866.96
# Equity available: $1,851.17
# Margin call: $15.79
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:50:00
# Equity required: $1,866.96
# Equity available: $1,851.17
# Margin call: $15.79
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:50:00
# Equity required: $1,866.96
# Equity available: $1,851.17
# Margin call: $15.79
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:50:00
# Equity required: $1,866.96
# Equity available: $1,851.17
# Margin call: $15.79
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:50:00
# Equity required: $1,866.96
# Equity available: $1,860.33
# Margin call: $6.63
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:55:00
# Equity required: $1,868.81
# Equity available: $1,859.53
# Margin call: $9.29
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:55:00
# Equity required: $1,868.81
# Equity available: $1,859.53
# Margin call: $9.29
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:55:00
# Equity required: $1,868.81
# Equity available: $1,859.53
# Margin call: $9.29
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:55:00
# Equity required: $1,868.81
# Equity available: $1,859.53
# Margin call: $9.29
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:55:00
# Equity required: $1,868.81
# Equity available: $1,859.53
# Margin call: $9.29
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:55:00
# Equity required: $1,868.81
# Equity available: $1,859.53
# Margin call: $9.29
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:55:00
# Equity required: $1,868.81
# Equity available: $1,859.53
# Margin call: $9.29
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:55:00
# Equity required: $1,868.81
# Equity available: $1,859.53
# Margin call: $9.29
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:55:00
# Equity required: $1,868.81
# Equity available: $1,859.53
# Margin call: $9.29
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:55:00
# Equity required: $1,868.81
# Equity available: $1,859.53
# Margin call: $9.29
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:55:00
# Equity required: $1,868.81
# Equity available: $1,859.53
# Margin call: $9.29
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:55:00
# Equity required: $1,868.81
# Equity available: $1,859.53
# Margin call: $9.29
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:55:00
# Equity required: $1,868.81
# Equity available: $1,859.53
# Margin call: $9.29
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 14:55:00
# Equity required: $1,868.81
# Equity available: $1,859.53
# Margin call: $9.29
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 15:00:00
# Equity required: $1,869.46
# Equity available: $1,866.23
# Margin call: $3.22
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 15:00:00
# Equity required: $1,869.46
# Equity available: $1,866.23
# Margin call: $3.22
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 15:00:00
# Equity required: $1,869.46
# Equity available: $1,866.23
# Margin call: $3.22
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 15:00:00
# Equity required: $1,869.46
# Equity available: $1,866.23
# Margin call: $3.22
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 15:00:00
# Equity required: $1,869.46
# Equity available: $1,866.23
# Margin call: $3.22
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 15:00:00
# Equity required: $1,869.46
# Equity available: $1,866.23
# Margin call: $3.22
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 15:00:00
# Equity required: $1,869.46
# Equity available: $1,866.23
# Margin call: $3.22
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 15:00:00
# Equity required: $1,869.46
# Equity available: $1,866.23
# Margin call: $3.22
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 15:00:00
# Equity required: $1,869.46
# Equity available: $1,866.23
# Margin call: $3.22
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 15:00:00
# Equity required: $1,869.46
# Equity available: $1,866.23
# Margin call: $3.22
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 15:00:00
# Equity required: $1,869.46
# Equity available: $1,866.23
# Margin call: $3.22
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 15:00:00
# Equity required: $1,869.46
# Equity available: $1,866.23
# Margin call: $3.22
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 15:00:00
# Equity required: $1,869.46
# Equity available: $1,866.23
# Margin call: $3.22
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 15:00:00
# Equity required: $1,869.46
# Equity available: $1,866.23
# Margin call: $3.22
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 18:20:00
# Equity required: $1,869.46
# Equity available: $1,869.42
# Margin call: $0.04
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 18:20:00
# Equity required: $1,869.46
# Equity available: $1,869.42
# Margin call: $0.04
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 18:20:00
# Equity required: $1,869.46
# Equity available: $1,869.42
# Margin call: $0.04
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 18:20:00
# Equity required: $1,869.46
# Equity available: $1,869.42
# Margin call: $0.04
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 18:20:00
# Equity required: $1,869.46
# Equity available: $1,869.42
# Margin call: $0.04
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 18:20:00
# Equity required: $1,869.46
# Equity available: $1,869.42
# Margin call: $0.04
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 18:20:00
# Equity required: $1,869.46
# Equity available: $1,869.42
# Margin call: $0.04
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 18:20:00
# Equity required: $1,869.46
# Equity available: $1,869.42
# Margin call: $0.04
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 18:20:00
# Equity required: $1,869.46
# Equity available: $1,869.42
# Margin call: $0.04
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 18:20:00
# Equity required: $1,869.46
# Equity available: $1,869.42
# Margin call: $0.04
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 18:20:00
# Equity required: $1,869.46
# Equity available: $1,869.42
# Margin call: $0.04
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 18:20:00
# Equity required: $1,869.46
# Equity available: $1,869.42
# Margin call: $0.04
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 18:20:00
# Equity required: $1,869.46
# Equity available: $1,869.42
# Margin call: $0.04
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 18:20:00
# Equity required: $1,869.46
# Equity available: $1,869.42
# Margin call: $0.04
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:00:00
# Equity required: $1,870.23
# Equity available: $1,866.35
# Margin call: $3.89
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:00:00
# Equity required: $1,870.23
# Equity available: $1,866.35
# Margin call: $3.89
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:00:00
# Equity required: $1,870.23
# Equity available: $1,866.35
# Margin call: $3.89
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:00:00
# Equity required: $1,870.23
# Equity available: $1,866.35
# Margin call: $3.89
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:00:00
# Equity required: $1,870.23
# Equity available: $1,866.35
# Margin call: $3.89
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:00:00
# Equity required: $1,870.23
# Equity available: $1,866.35
# Margin call: $3.89
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:00:00
# Equity required: $1,870.23
# Equity available: $1,866.35
# Margin call: $3.89
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:00:00
# Equity required: $1,870.23
# Equity available: $1,866.35
# Margin call: $3.89
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:00:00
# Equity required: $1,870.23
# Equity available: $1,866.35
# Margin call: $3.89
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:00:00
# Equity required: $1,870.23
# Equity available: $1,866.35
# Margin call: $3.89
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:00:00
# Equity required: $1,870.23
# Equity available: $1,866.35
# Margin call: $3.89
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:00:00
# Equity required: $1,870.23
# Equity available: $1,866.35
# Margin call: $3.89
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:00:00
# Equity required: $1,870.23
# Equity available: $1,866.35
# Margin call: $3.89
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:00:00
# Equity required: $1,870.23
# Equity available: $1,866.35
# Margin call: $3.89
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:05:00
# Equity required: $1,871.13
# Equity available: $1,866.63
# Margin call: $4.50
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:05:00
# Equity required: $1,871.13
# Equity available: $1,866.63
# Margin call: $4.50
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:05:00
# Equity required: $1,871.13
# Equity available: $1,866.63
# Margin call: $4.50
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:05:00
# Equity required: $1,871.13
# Equity available: $1,866.63
# Margin call: $4.50
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:05:00
# Equity required: $1,871.13
# Equity available: $1,866.63
# Margin call: $4.50
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:05:00
# Equity required: $1,871.13
# Equity available: $1,866.63
# Margin call: $4.50
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:05:00
# Equity required: $1,871.13
# Equity available: $1,866.63
# Margin call: $4.50
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:05:00
# Equity required: $1,871.13
# Equity available: $1,866.63
# Margin call: $4.50
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:05:00
# Equity required: $1,871.13
# Equity available: $1,866.63
# Margin call: $4.50
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:05:00
# Equity required: $1,871.13
# Equity available: $1,866.63
# Margin call: $4.50
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:05:00
# Equity required: $1,871.13
# Equity available: $1,866.63
# Margin call: $4.50
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:05:00
# Equity required: $1,871.13
# Equity available: $1,866.63
# Margin call: $4.50
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:05:00
# Equity required: $1,871.13
# Equity available: $1,866.63
# Margin call: $4.50
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:05:00
# Equity required: $1,871.13
# Equity available: $1,866.63
# Margin call: $4.50
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:30:00
# Equity required: $1,871.21
# Equity available: $1,870.83
# Margin call: $0.39
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:30:00
# Equity required: $1,871.21
# Equity available: $1,870.83
# Margin call: $0.39
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:30:00
# Equity required: $1,871.21
# Equity available: $1,870.83
# Margin call: $0.39
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:30:00
# Equity required: $1,871.21
# Equity available: $1,870.83
# Margin call: $0.39
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:30:00
# Equity required: $1,871.21
# Equity available: $1,870.83
# Margin call: $0.39
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:30:00
# Equity required: $1,871.21
# Equity available: $1,870.83
# Margin call: $0.39
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:30:00
# Equity required: $1,871.21
# Equity available: $1,870.83
# Margin call: $0.39
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:30:00
# Equity required: $1,871.21
# Equity available: $1,870.83
# Margin call: $0.39
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:30:00
# Equity required: $1,871.21
# Equity available: $1,870.83
# Margin call: $0.39
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:30:00
# Equity required: $1,871.21
# Equity available: $1,870.83
# Margin call: $0.39
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:30:00
# Equity required: $1,871.21
# Equity available: $1,870.83
# Margin call: $0.39
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:30:00
# Equity required: $1,871.21
# Equity available: $1,870.83
# Margin call: $0.39
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:30:00
# Equity required: $1,871.21
# Equity available: $1,870.83
# Margin call: $0.39
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:30:00
# Equity required: $1,871.21
# Equity available: $1,870.83
# Margin call: $0.39
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:35:00
# Equity required: $1,871.33
# Equity available: $1,870.71
# Margin call: $0.62
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:35:00
# Equity required: $1,871.33
# Equity available: $1,870.71
# Margin call: $0.62
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:35:00
# Equity required: $1,871.33
# Equity available: $1,870.71
# Margin call: $0.62
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:35:00
# Equity required: $1,871.33
# Equity available: $1,870.71
# Margin call: $0.62
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:35:00
# Equity required: $1,871.33
# Equity available: $1,870.71
# Margin call: $0.62
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:35:00
# Equity required: $1,871.33
# Equity available: $1,870.71
# Margin call: $0.62
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:35:00
# Equity required: $1,871.33
# Equity available: $1,870.71
# Margin call: $0.62
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:35:00
# Equity required: $1,871.33
# Equity available: $1,870.71
# Margin call: $0.62
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:35:00
# Equity required: $1,871.33
# Equity available: $1,870.71
# Margin call: $0.62
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:35:00
# Equity required: $1,871.33
# Equity available: $1,870.71
# Margin call: $0.62
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:35:00
# Equity required: $1,871.33
# Equity available: $1,870.71
# Margin call: $0.62
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:35:00
# Equity required: $1,871.33
# Equity available: $1,870.71
# Margin call: $0.62
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:35:00
# Equity required: $1,871.33
# Equity available: $1,870.71
# Margin call: $0.62
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-14 19:35:00
# Equity required: $1,871.33
# Equity available: $1,870.71
# Margin call: $0.62
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-15 13:45:00
# Equity required: $1,877.09
# Equity available: $1,848.29
# Margin call: $28.80
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-15 13:45:00
# Equity required: $1,877.09
# Equity available: $1,848.29
# Margin call: $28.80
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-15 13:45:00
# Equity required: $1,877.09
# Equity available: $1,848.29
# Margin call: $28.80
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-15 13:45:00
# Equity required: $1,877.09
# Equity available: $1,848.29
# Margin call: $28.80
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-15 13:45:00
# Equity required: $1,877.09
# Equity available: $1,848.29
# Margin call: $28.80
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-15 13:45:00
# Equity required: $1,877.09
# Equity available: $1,848.29
# Margin call: $28.80
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-15 13:45:00
# Equity required: $1,877.09
# Equity available: $1,848.29
# Margin call: $28.80
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-15 13:45:00
# Equity required: $1,877.09
# Equity available: $1,848.29
# Margin call: $28.80
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-15 13:45:00
# Equity required: $1,877.09
# Equity available: $1,848.29
# Margin call: $28.80
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-15 13:45:00
# Equity required: $1,877.09
# Equity available: $1,848.29
# Margin call: $28.80
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-15 13:45:00
# Equity required: $1,877.09
# Equity available: $1,848.29
# Margin call: $28.80
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-15 13:45:00
# Equity required: $1,877.09
# Equity available: $1,848.29
# Margin call: $28.80
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-15 13:45:00
# Equity required: $1,877.09
# Equity available: $1,848.29
# Margin call: $28.80
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-15 13:45:00
# Equity required: $1,877.09
# Equity available: $1,848.29
# Margin call: $28.80
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-15 13:45:00
# Equity required: $1,877.09
# Equity available: $1,857.18
# Margin call: $19.91
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-07-15 13:45:00
# Equity required: $1,877.09
# Equity available: $1,872.17
# Margin call: $4.92
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:35:00
# Equity required: $1,880.03
# Equity available: $1,863.73
# Margin call: $16.30
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:35:00
# Equity required: $1,880.03
# Equity available: $1,863.73
# Margin call: $16.30
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:35:00
# Equity required: $1,880.03
# Equity available: $1,863.73
# Margin call: $16.30
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:35:00
# Equity required: $1,880.03
# Equity available: $1,863.73
# Margin call: $16.30
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:35:00
# Equity required: $1,880.03
# Equity available: $1,863.73
# Margin call: $16.30
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:35:00
# Equity required: $1,880.03
# Equity available: $1,863.73
# Margin call: $16.30
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:35:00
# Equity required: $1,880.03
# Equity available: $1,863.73
# Margin call: $16.30
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:35:00
# Equity required: $1,880.03
# Equity available: $1,863.73
# Margin call: $16.30
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:35:00
# Equity required: $1,880.03
# Equity available: $1,863.73
# Margin call: $16.30
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:35:00
# Equity required: $1,880.03
# Equity available: $1,863.73
# Margin call: $16.30
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:35:00
# Equity required: $1,880.03
# Equity available: $1,863.73
# Margin call: $16.30
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:35:00
# Equity required: $1,880.03
# Equity available: $1,863.73
# Margin call: $16.30
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:35:00
# Equity required: $1,880.03
# Equity available: $1,863.73
# Margin call: $16.30
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:35:00
# Equity required: $1,880.03
# Equity available: $1,863.73
# Margin call: $16.30
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:35:00
# Equity required: $1,880.03
# Equity available: $1,863.73
# Margin call: $16.30
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:35:00
# Equity required: $1,880.03
# Equity available: $1,863.73
# Margin call: $16.30
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:35:00
# Equity required: $1,880.03
# Equity available: $1,871.55
# Margin call: $8.48
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:35:00
# Equity required: $1,880.03
# Equity available: $1,865.44
# Margin call: $14.60
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:40:00
# Equity required: $1,880.35
# Equity available: $1,878.79
# Margin call: $1.56
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:40:00
# Equity required: $1,880.35
# Equity available: $1,878.79
# Margin call: $1.56
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:40:00
# Equity required: $1,880.35
# Equity available: $1,878.79
# Margin call: $1.56
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:40:00
# Equity required: $1,880.35
# Equity available: $1,878.79
# Margin call: $1.56
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:40:00
# Equity required: $1,880.35
# Equity available: $1,878.79
# Margin call: $1.56
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:40:00
# Equity required: $1,880.35
# Equity available: $1,878.79
# Margin call: $1.56
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:40:00
# Equity required: $1,880.35
# Equity available: $1,878.79
# Margin call: $1.56
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:40:00
# Equity required: $1,880.35
# Equity available: $1,878.79
# Margin call: $1.56
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:40:00
# Equity required: $1,880.35
# Equity available: $1,878.79
# Margin call: $1.56
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:40:00
# Equity required: $1,880.35
# Equity available: $1,878.79
# Margin call: $1.56
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:40:00
# Equity required: $1,880.35
# Equity available: $1,878.79
# Margin call: $1.56
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:40:00
# Equity required: $1,880.35
# Equity available: $1,878.79
# Margin call: $1.56
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:40:00
# Equity required: $1,880.35
# Equity available: $1,878.79
# Margin call: $1.56
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:40:00
# Equity required: $1,880.35
# Equity available: $1,878.79
# Margin call: $1.56
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:40:00
# Equity required: $1,880.35
# Equity available: $1,878.79
# Margin call: $1.56
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:40:00
# Equity required: $1,880.35
# Equity available: $1,878.79
# Margin call: $1.56
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:40:00
# Equity required: $1,880.35
# Equity available: $1,878.79
# Margin call: $1.56
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 13:40:00
# Equity required: $1,880.35
# Equity available: $1,878.79
# Margin call: $1.56
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 17:50:00
# Equity required: $1,882.41
# Equity available: $1,872.03
# Margin call: $10.38
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 17:50:00
# Equity required: $1,882.41
# Equity available: $1,872.03
# Margin call: $10.38
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 17:50:00
# Equity required: $1,882.41
# Equity available: $1,872.03
# Margin call: $10.38
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 17:50:00
# Equity required: $1,882.41
# Equity available: $1,872.03
# Margin call: $10.38
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 17:50:00
# Equity required: $1,882.41
# Equity available: $1,872.03
# Margin call: $10.38
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 17:50:00
# Equity required: $1,882.41
# Equity available: $1,872.03
# Margin call: $10.38
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 17:50:00
# Equity required: $1,882.41
# Equity available: $1,872.03
# Margin call: $10.38
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 17:50:00
# Equity required: $1,882.41
# Equity available: $1,872.03
# Margin call: $10.38
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 17:50:00
# Equity required: $1,882.41
# Equity available: $1,872.03
# Margin call: $10.38
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 17:50:00
# Equity required: $1,882.41
# Equity available: $1,872.03
# Margin call: $10.38
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 17:50:00
# Equity required: $1,882.41
# Equity available: $1,872.03
# Margin call: $10.38
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 17:50:00
# Equity required: $1,882.41
# Equity available: $1,872.03
# Margin call: $10.38
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 17:50:00
# Equity required: $1,882.41
# Equity available: $1,872.03
# Margin call: $10.38
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 17:50:00
# Equity required: $1,882.41
# Equity available: $1,872.03
# Margin call: $10.38
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 17:50:00
# Equity required: $1,882.41
# Equity available: $1,872.03
# Margin call: $10.38
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 17:50:00
# Equity required: $1,882.41
# Equity available: $1,872.03
# Margin call: $10.38
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 17:50:00
# Equity required: $1,882.41
# Equity available: $1,872.03
# Margin call: $10.38
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 17:50:00
# Equity required: $1,882.41
# Equity available: $1,872.03
# Margin call: $10.38
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 17:55:00
# Equity required: $1,883.67
# Equity available: $1,877.37
# Margin call: $6.30
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 17:55:00
# Equity required: $1,883.67
# Equity available: $1,877.37
# Margin call: $6.30
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2021-08-16 17:55:00
# Equity required: $1,883.67
# ...
# Equity required: $2,161.07
# Equity available: $2,149.50
# Margin call: $11.58
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-15 15:35:00
# Equity required: $2,161.07
# Equity available: $2,149.50
# Margin call: $11.58
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-15 15:35:00
# Equity required: $2,161.07
# Equity available: $2,149.50
# Margin call: $11.58
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-15 15:35:00
# Equity required: $2,161.07
# Equity available: $2,149.50
# Margin call: $11.58
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-15 15:40:00
# Equity required: $2,164.70
# Equity available: $2,146.55
# Margin call: $18.15
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-15 15:40:00
# Equity required: $2,164.70
# Equity available: $2,146.55
# Margin call: $18.15
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-15 15:40:00
# Equity required: $2,164.70
# Equity available: $2,146.55
# Margin call: $18.15
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-15 15:40:00
# Equity required: $2,164.70
# Equity available: $2,146.55
# Margin call: $18.15
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-15 15:40:00
# Equity required: $2,164.70
# Equity available: $2,146.55
# Margin call: $18.15
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-15 15:45:00
# Equity required: $2,167.63
# Equity available: $2,152.99
# Margin call: $14.64
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-15 15:45:00
# Equity required: $2,167.63
# Equity available: $2,152.99
# Margin call: $14.64
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-15 15:45:00
# Equity required: $2,167.63
# Equity available: $2,152.99
# Margin call: $14.64
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-15 15:45:00
# Equity required: $2,167.63
# Equity available: $2,152.99
# Margin call: $14.64
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-15 15:45:00
# Equity required: $2,167.63
# Equity available: $2,152.99
# Margin call: $14.64
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-15 16:25:00
# Equity required: $2,168.33
# Equity available: $2,164.82
# Margin call: $3.51
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-15 16:25:00
# Equity required: $2,168.33
# Equity available: $2,164.82
# Margin call: $3.51
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-15 16:25:00
# Equity required: $2,168.33
# Equity available: $2,164.82
# Margin call: $3.51
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-15 16:25:00
# Equity required: $2,168.33
# Equity available: $2,164.82
# Margin call: $3.51
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-15 16:25:00
# Equity required: $2,168.33
# Equity available: $2,164.82
# Margin call: $3.51
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-15 16:30:00
# Equity required: $2,168.58
# Equity available: $2,167.33
# Margin call: $1.25
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-15 16:30:00
# Equity required: $2,168.58
# Equity available: $2,167.33
# Margin call: $1.25
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-15 16:30:00
# Equity required: $2,168.58
# Equity available: $2,167.33
# Margin call: $1.25
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-15 16:30:00
# Equity required: $2,168.58
# Equity available: $2,167.33
# Margin call: $1.25
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-15 16:30:00
# Equity required: $2,168.58
# Equity available: $2,167.33
# Margin call: $1.25
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-15 19:20:00
# Equity required: $2,169.52
# Equity available: $2,164.79
# Margin call: $4.73
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-15 19:20:00
# Equity required: $2,169.52
# Equity available: $2,164.79
# Margin call: $4.73
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-15 19:20:00
# Equity required: $2,169.52
# Equity available: $2,164.79
# Margin call: $4.73
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-15 19:20:00
# Equity required: $2,169.52
# Equity available: $2,164.79
# Margin call: $4.73
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-15 19:20:00
# Equity required: $2,169.52
# Equity available: $2,164.79
# Margin call: $4.73
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-16 18:05:00
# Equity required: $2,171.22
# Equity available: $2,162.64
# Margin call: $8.58
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-16 18:05:00
# Equity required: $2,171.22
# Equity available: $2,162.64
# Margin call: $8.58
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-16 18:05:00
# Equity required: $2,171.22
# Equity available: $2,162.64
# Margin call: $8.58
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-16 18:05:00
# Equity required: $2,171.22
# Equity available: $2,162.64
# Margin call: $8.58
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-16 18:05:00
# Equity required: $2,171.22
# Equity available: $2,162.64
# Margin call: $8.58
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-16 18:10:00
# Equity required: $2,173.21
# Equity available: $2,163.26
# Margin call: $9.95
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-16 18:10:00
# Equity required: $2,173.21
# Equity available: $2,163.26
# Margin call: $9.95
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-16 18:10:00
# Equity required: $2,173.21
# Equity available: $2,163.26
# Margin call: $9.95
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-16 18:10:00
# Equity required: $2,173.21
# Equity available: $2,163.26
# Margin call: $9.95
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-16 18:10:00
# Equity required: $2,173.21
# Equity available: $2,163.26
# Margin call: $9.95
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 13:45:00
# Equity required: $2,178.08
# Equity available: $2,153.71
# Margin call: $24.38
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 13:45:00
# Equity required: $2,178.08
# Equity available: $2,153.71
# Margin call: $24.38
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 13:45:00
# Equity required: $2,178.08
# Equity available: $2,153.71
# Margin call: $24.38
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 13:45:00
# Equity required: $2,178.08
# Equity available: $2,153.71
# Margin call: $24.38
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 13:45:00
# Equity required: $2,178.08
# Equity available: $2,153.71
# Margin call: $24.38
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 13:55:00
# Equity required: $2,179.85
# Equity available: $2,171.03
# Margin call: $8.82
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 13:55:00
# Equity required: $2,179.85
# Equity available: $2,171.03
# Margin call: $8.82
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 13:55:00
# Equity required: $2,179.85
# Equity available: $2,171.03
# Margin call: $8.82
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 13:55:00
# Equity required: $2,179.85
# Equity available: $2,171.03
# Margin call: $8.82
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 13:55:00
# Equity required: $2,179.85
# Equity available: $2,171.03
# Margin call: $8.82
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 14:00:00
# Equity required: $2,180.35
# Equity available: $2,177.84
# Margin call: $2.50
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 14:00:00
# Equity required: $2,180.35
# Equity available: $2,177.84
# Margin call: $2.50
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 14:00:00
# Equity required: $2,180.35
# Equity available: $2,177.84
# Margin call: $2.50
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 14:00:00
# Equity required: $2,180.35
# Equity available: $2,177.84
# Margin call: $2.50
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 14:00:00
# Equity required: $2,180.35
# Equity available: $2,177.84
# Margin call: $2.50
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 17:00:00
# Equity required: $2,181.10
# Equity available: $2,177.30
# Margin call: $3.79
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 17:00:00
# Equity required: $2,181.10
# Equity available: $2,177.30
# Margin call: $3.79
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 17:00:00
# Equity required: $2,181.10
# Equity available: $2,177.30
# Margin call: $3.79
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 17:00:00
# Equity required: $2,181.10
# Equity available: $2,177.30
# Margin call: $3.79
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 17:00:00
# Equity required: $2,181.10
# Equity available: $2,177.30
# Margin call: $3.79
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 17:10:00
# Equity required: $2,185.67
# Equity available: $2,162.82
# Margin call: $22.84
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 17:10:00
# Equity required: $2,185.67
# Equity available: $2,162.82
# Margin call: $22.84
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 17:10:00
# Equity required: $2,185.67
# Equity available: $2,162.82
# Margin call: $22.84
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 17:10:00
# Equity required: $2,185.67
# Equity available: $2,162.82
# Margin call: $22.84
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 17:10:00
# Equity required: $2,185.67
# Equity available: $2,162.82
# Margin call: $22.84
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 18:00:00
# Equity required: $2,188.61
# Equity available: $2,173.89
# Margin call: $14.72
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 18:00:00
# Equity required: $2,188.61
# Equity available: $2,173.89
# Margin call: $14.72
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 18:00:00
# Equity required: $2,188.61
# Equity available: $2,173.89
# Margin call: $14.72
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 18:00:00
# Equity required: $2,188.61
# Equity available: $2,173.89
# Margin call: $14.72
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 18:00:00
# Equity required: $2,188.61
# Equity available: $2,173.89
# Margin call: $14.72
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 18:05:00
# Equity required: $2,195.38
# Equity available: $2,161.53
# Margin call: $33.85
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 18:05:00
# Equity required: $2,195.38
# Equity available: $2,161.53
# Margin call: $33.85
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 18:05:00
# Equity required: $2,195.38
# Equity available: $2,161.53
# Margin call: $33.85
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 18:05:00
# Equity required: $2,195.38
# Equity available: $2,161.53
# Margin call: $33.85
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 18:05:00
# Equity required: $2,195.38
# Equity available: $2,161.53
# Margin call: $33.85
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 18:10:00
# Equity required: $2,197.48
# Equity available: $2,186.96
# Margin call: $10.52
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 18:10:00
# Equity required: $2,197.48
# Equity available: $2,186.96
# Margin call: $10.52
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 18:10:00
# Equity required: $2,197.48
# Equity available: $2,186.96
# Margin call: $10.52
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 18:10:00
# Equity required: $2,197.48
# Equity available: $2,186.96
# Margin call: $10.52
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 18:10:00
# Equity required: $2,197.48
# Equity available: $2,186.96
# Margin call: $10.52
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 18:25:00
# Equity required: $2,198.56
# Equity available: $2,193.17
# Margin call: $5.39
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 18:25:00
# Equity required: $2,198.56
# Equity available: $2,193.17
# Margin call: $5.39
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 18:25:00
# Equity required: $2,198.56
# Equity available: $2,193.17
# Margin call: $5.39
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 18:25:00
# Equity required: $2,198.56
# Equity available: $2,193.17
# Margin call: $5.39
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 18:25:00
# Equity required: $2,198.56
# Equity available: $2,193.17
# Margin call: $5.39
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 18:30:00
# Equity required: $2,200.87
# Equity available: $2,189.29
# Margin call: $11.58
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 18:30:00
# Equity required: $2,200.87
# Equity available: $2,189.29
# Margin call: $11.58
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 18:30:00
# Equity required: $2,200.87
# Equity available: $2,189.29
# Margin call: $11.58
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 18:30:00
# Equity required: $2,200.87
# Equity available: $2,189.29
# Margin call: $11.58
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 18:30:00
# Equity required: $2,200.87
# Equity available: $2,189.29
# Margin call: $11.58
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 18:35:00
# Equity required: $2,204.00
# Equity available: $2,188.36
# Margin call: $15.65
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 18:35:00
# Equity required: $2,204.00
# Equity available: $2,188.36
# Margin call: $15.65
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 18:35:00
# Equity required: $2,204.00
# Equity available: $2,188.36
# Margin call: $15.65
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 18:35:00
# Equity required: $2,204.00
# Equity available: $2,188.36
# Margin call: $15.65
# ========================
#
# === MARGIN CALL INFO ===
# Margin call for AAPL at 2022-08-17 18:35:00
# Equity required: $2,204.00
# Equity available: $2,188.36
# Margin call: $15.65
# ========================

# %%
plt.figure()
plt.plot(portfolio_value, color=colors[0], label=f'Portfolio value\n${capital:,.2f}')
plt.title('Portfolio value over time')
plt.xlabel('Time')
plt.ylabel('Value ($)')
plt.legend()
plt.show()
